# %% [markdown]
# # distance analysis

# %% [markdown]
# This notebook looks at the spatial relations between parks and apartment listings scraped from craigslist. First, I subset the craigslist file to only include those that include parks in their descriptions and convert to a geodataframe. After reading the county parks dataframe, I establish a centroid and project both dataframes to the same projection.

# %%
import pandas as pd 
park = pd.read_pickle("combined_df_sorted.pkl")
park.head()
# Out:
#                                                  urls   price
# 2   https://losangeles.craigslist.org/wst/apa/d/lo...  2178.0  \
# 10  https://losangeles.craigslist.org/wst/apa/d/lo...  2250.0
# 14  https://losangeles.craigslist.org/wst/apa/d/lo...  3499.0
# 15  https://losangeles.craigslist.org/wst/apa/d/lo...  2275.0
# 16  https://losangeles.craigslist.org/lac/apa/d/lo...  1775.0
#
#                                           description        lat        long
# 2   welcome to casa de vida apartments west la liv...  34.028928 -118.415252  \
# 10   bedroom bath available now per month w el seg...  33.916308 -118.287922
# 14  featuring lush vegetation a koi pond fountains...  34.066000 -118.474000
# 15  unit availability july welcome to burton squar...  34.072109 -118.380919
# 16  moments away from hollywood boulevard cherokee...  34.102073 -118.335110
#
#     bedrooms  bathrooms   sqft  park_TF
# 2        0.0        1.0  475.0     True  \
# 10       2.0        1.0  775.0    False
# 14       1.0        1.0  800.0    False
# 15       1.0        1.0  837.0    False
# 16       0.0        1.0  500.0    False
#
#                                           park_T_why
# 2   [parks nearby, public parks, public park, parks]
# 10                                                []
# 14                                                []
# 15                                                []
# 16                                                []

# %%
park.shape
# Out:
# (7403, 10)

# %%
parktrue = park[park['park_TF'] == True]

# %%
parktrue.shape
# Out:
# (1434, 10)

# %%
import geopandas as gpd
parks = gpd.read_file('county_parks.geojson')

# %%
parks.to_crs('EPSG:3497', inplace=True)

# %%
parks['centroid'] = parks.centroid
parks.head(1)
# Out:
#    OBJECTID  UNIT_ID   LMS_ID       PARK_NAME        PARK_LBL   ACCESS_TYP
# 0         1     30.0  23603.0  El Barrio Park  El Barrio Park  Open Access  \
#
#    RPT_ACRES  GIS_ACRES          AGNCY_NAME AGNCY_LEV  ...
# 0      2.093   2.092992  Claremont, City of      City  ...  \
#
#               ADDRESS       CITY    ZIP HOURS PHONES IS_COUNTY   Shape__Area
# 0  400 Claremont Blvd  Claremont  91711   NaN    NaN        No  91170.362305  \
#
#   Shape__Length                                           geometry
# 0   1451.547906  POLYGON ((2027330.308 566315.335, 2027294.750 ...  \
#
#                          centroid
# 0  POINT (2027274.179 566272.313)
#
# [1 rows x 54 columns]

# %%
parks.shape
# Out:
# (3012, 54)

# %%
parktrue = gpd.GeoDataFrame(parktrue, geometry=gpd.points_from_xy(parktrue.long, parktrue.lat), crs="EPSG:4326")
parktrue.head(1)
# Out:
#                                                 urls   price
# 2  https://losangeles.craigslist.org/wst/apa/d/lo...  2178.0  \
#
#                                          description        lat        long
# 2  welcome to casa de vida apartments west la liv...  34.028928 -118.415252  \
#
#    bedrooms  bathrooms   sqft  park_TF
# 2       0.0        1.0  475.0     True  \
#
#                                          park_T_why
# 2  [parks nearby, public parks, public park, parks]  \
#
#                       geometry
# 2  POINT (-118.41525 34.02893)

# %%
parks.to_crs('EPSG:3497', inplace=True)
parktrue.to_crs('EPSG:3497', inplace=True)

# %%
parks.head(1)
# Out:
#    OBJECTID  UNIT_ID   LMS_ID       PARK_NAME        PARK_LBL   ACCESS_TYP
# 0         1     30.0  23603.0  El Barrio Park  El Barrio Park  Open Access  \
#
#    RPT_ACRES  GIS_ACRES          AGNCY_NAME AGNCY_LEV  ...
# 0      2.093   2.092992  Claremont, City of      City  ...  \
#
#               ADDRESS       CITY    ZIP HOURS PHONES IS_COUNTY   Shape__Area
# 0  400 Claremont Blvd  Claremont  91711   NaN    NaN        No  91170.362305  \
#
#   Shape__Length                                           geometry
# 0   1451.547906  POLYGON ((2027330.308 566315.335, 2027294.750 ...  \
#
#                          centroid
# 0  POINT (2027274.179 566272.313)
#
# [1 rows x 54 columns]

# %%
parks = parks[['OBJECTID', 'PARK_NAME', 'RPT_ACRES', 'ADDRESS', 'CITY', 
              'ZIP', 'Shape__Area', 'Shape__Length', 'geometry', 'centroid']]
parks.head(1)
# Out:
#    OBJECTID       PARK_NAME  RPT_ACRES             ADDRESS       CITY    ZIP
# 0         1  El Barrio Park      2.093  400 Claremont Blvd  Claremont  91711  \
#
#     Shape__Area  Shape__Length
# 0  91170.362305    1451.547906  \
#
#                                             geometry
# 0  POLYGON ((2027330.308 566315.335, 2027294.750 ...  \
#
#                          centroid
# 0  POINT (2027274.179 566272.313)

# %% [markdown]
# After subsetting the datasets, I conduct a spatial join and establish a distance column, checking the joined dataframe shape to make sure that listings were preserved.

# %%
join = parktrue.sjoin_nearest(parks, distance_col='distance')
join.shape
# Out:
# (1461, 22)

# %%
join.head(10)
# Out:
#                                                    urls   price
# 2     https://losangeles.craigslist.org/wst/apa/d/lo...  2178.0  \
# 215   https://losangeles.craigslist.org/wst/apa/d/lo...  2178.0
# 293   https://losangeles.craigslist.org/wst/apa/7630...  2875.0
# 528   https://losangeles.craigslist.org/wst/apa/d/lo...  2178.0
# 1087  https://losangeles.craigslist.org/wst/apa/d/lo...  2178.0
# 1526  https://losangeles.craigslist.org/wst/apa/d/lo...  2178.0
# 1542  https://losangeles.craigslist.org/wst/apa/d/lo...  2395.0
# 1782  https://losangeles.craigslist.org/wst/apa/d/lo...  2395.0
# 1886  https://losangeles.craigslist.org/wst/apa/d/lo...  2178.0
# 2867  https://losangeles.craigslist.org/wst/apa/d/lo...  1200.0
#
#                                             description        lat
# 2     welcome to casa de vida apartments west la liv...  34.028928  \
# 215    off when you sign a month lease casa de vida ...  34.028928
# 293   casa de vida unit availability june apartment ...  34.028928
# 528    off when you sign a month lease casa de vida ...  34.028928
# 1087   off when you sign a month lease casa de vida ...  34.028928
# 1526  casa de vida off when you sign a month lease o...  34.028928
# 1542  unit availability june discover your new home ...  34.029777
# 1782  unit availability june discover your new home ...  34.029777
# 1886  casa de vida off when you sign a month lease a...  34.028928
# 2867  spacious bedroom bath apartment unique vintage...  34.036011
#
#             long  bedrooms  bathrooms    sqft  park_TF
# 2    -118.415252       0.0        1.0   475.0     True  \
# 215  -118.415252       0.0        1.0   475.0     True
# 293  -118.415252       2.0        2.0  1010.0     True
# 528  -118.415252       0.0        1.0   475.0     True
# 1087 -118.415252       0.0        1.0   475.0     True
# 1526 -118.415252       0.0        1.0   475.0     True
# 1542 -118.415267       1.0        1.0   660.0     True
# 1782 -118.415267       1.0        1.0   660.0     True
# 1886 -118.415252       0.0        1.0   475.0     True
# 2867 -118.434552       0.0        1.0     NaN     True
#
#                                             park_T_why  ... OBJECTID
# 2     [parks nearby, public parks, public park, parks]  ...      275  \
# 215   [parks nearby, public parks, public park, parks]  ...      275
# 293   [parks nearby, public parks, public park, parks]  ...      275
# 528   [parks nearby, public parks, public park, parks]  ...      275
# 1087  [parks nearby, public parks, public park, parks]  ...      275
# 1526  [parks nearby, public parks, public park, parks]  ...      275
# 1542                               [recreation center]  ...      275
# 1782                               [recreation center]  ...      275
# 1886  [parks nearby, public parks, public park, parks]  ...      275
# 2867                                   [westwood park]  ...      275
#
#                              PARK_NAME  RPT_ACRES             ADDRESS
# 2     Palms Park (City of Los Angeles)      2.703  2950  Overland Ave  \
# 215   Palms Park (City of Los Angeles)      2.703  2950  Overland Ave
# 293   Palms Park (City of Los Angeles)      2.703  2950  Overland Ave
# 528   Palms Park (City of Los Angeles)      2.703  2950  Overland Ave
# 1087  Palms Park (City of Los Angeles)      2.703  2950  Overland Ave
# 1526  Palms Park (City of Los Angeles)      2.703  2950  Overland Ave
# 1542  Palms Park (City of Los Angeles)      2.703  2950  Overland Ave
# 1782  Palms Park (City of Los Angeles)      2.703  2950  Overland Ave
# 1886  Palms Park (City of Los Angeles)      2.703  2950  Overland Ave
# 2867  Palms Park (City of Los Angeles)      2.703  2950  Overland Ave
#
#              CITY    ZIP    Shape__Area Shape__Length
# 2     Los Angeles  90064  117732.124023   2484.284534  \
# 215   Los Angeles  90064  117732.124023   2484.284534
# 293   Los Angeles  90064  117732.124023   2484.284534
# 528   Los Angeles  90064  117732.124023   2484.284534
# 1087  Los Angeles  90064  117732.124023   2484.284534
# 1526  Los Angeles  90064  117732.124023   2484.284534
# 1542  Los Angeles  90064  117732.124023   2484.284534
# 1782  Los Angeles  90064  117732.124023   2484.284534
# 1886  Los Angeles  90064  117732.124023   2484.284534
# 2867  Los Angeles  90064  117732.124023   2484.284534
#
#                             centroid     distance
# 2     POINT (1961480.614 559268.459)   462.655676
# 215   POINT (1961480.614 559268.459)   462.655676
# 293   POINT (1961480.614 559268.459)   462.655676
# 528   POINT (1961480.614 559268.459)   462.655676
# 1087  POINT (1961480.614 559268.459)   462.655676
# 1526  POINT (1961480.614 559268.459)   462.655676
# 1542  POINT (1961480.614 559268.459)   380.376555
# 1782  POINT (1961480.614 559268.459)   380.376555
# 1886  POINT (1961480.614 559268.459)   462.655676
# 2867  POINT (1961480.614 559268.459)  1560.755574
#
# [10 rows x 22 columns]

# %%
pd.set_option('display.max_columns', None)
join.head()
# Out:
#                                                    urls   price
# 2     https://losangeles.craigslist.org/wst/apa/d/lo...  2178.0  \
# 215   https://losangeles.craigslist.org/wst/apa/d/lo...  2178.0
# 293   https://losangeles.craigslist.org/wst/apa/7630...  2875.0
# 528   https://losangeles.craigslist.org/wst/apa/d/lo...  2178.0
# 1087  https://losangeles.craigslist.org/wst/apa/d/lo...  2178.0
#
#                                             description        lat
# 2     welcome to casa de vida apartments west la liv...  34.028928  \
# 215    off when you sign a month lease casa de vida ...  34.028928
# 293   casa de vida unit availability june apartment ...  34.028928
# 528    off when you sign a month lease casa de vida ...  34.028928
# 1087   off when you sign a month lease casa de vida ...  34.028928
#
#             long  bedrooms  bathrooms    sqft  park_TF
# 2    -118.415252       0.0        1.0   475.0     True  \
# 215  -118.415252       0.0        1.0   475.0     True
# 293  -118.415252       2.0        2.0  1010.0     True
# 528  -118.415252       0.0        1.0   475.0     True
# 1087 -118.415252       0.0        1.0   475.0     True
#
#                                             park_T_why
# 2     [parks nearby, public parks, public park, parks]  \
# 215   [parks nearby, public parks, public park, parks]
# 293   [parks nearby, public parks, public park, parks]
# 528   [parks nearby, public parks, public park, parks]
# 1087  [parks nearby, public parks, public park, parks]
#
#                             geometry  index_right  OBJECTID
# 2     POINT (1961650.114 558751.186)          274       275  \
# 215   POINT (1961650.114 558751.186)          274       275
# 293   POINT (1961650.114 558751.186)          274       275
# 528   POINT (1961650.114 558751.186)          274       275
# 1087  POINT (1961650.114 558751.186)          274       275
#
#                              PARK_NAME  RPT_ACRES             ADDRESS
# 2     Palms Park (City of Los Angeles)      2.703  2950  Overland Ave  \
# 215   Palms Park (City of Los Angeles)      2.703  2950  Overland Ave
# 293   Palms Park (City of Los Angeles)      2.703  2950  Overland Ave
# 528   Palms Park (City of Los Angeles)      2.703  2950  Overland Ave
# 1087  Palms Park (City of Los Angeles)      2.703  2950  Overland Ave
#
#              CITY    ZIP    Shape__Area  Shape__Length
# 2     Los Angeles  90064  117732.124023    2484.284534  \
# 215   Los Angeles  90064  117732.124023    2484.284534
# 293   Los Angeles  90064  117732.124023    2484.284534
# 528   Los Angeles  90064  117732.124023    2484.284534
# 1087  Los Angeles  90064  117732.124023    2484.284534
#
#                             centroid    distance
# 2     POINT (1961480.614 559268.459)  462.655676
# 215   POINT (1961480.614 559268.459)  462.655676
# 293   POINT (1961480.614 559268.459)  462.655676
# 528   POINT (1961480.614 559268.459)  462.655676
# 1087  POINT (1961480.614 559268.459)  462.655676

# %% [markdown]
# To create a map showing the connection between parks and listings, I convert the distance column to line geometry. To simplify the dataset, I then subset it further and project it for the map. Although there were a few listings in the San Fernando Valley, I focus the map on downtown and west LA where listings with parks in their descriptions are mentioned. Notably, most listings, irrespective of parks, were concentrated in this area even though there are many other parks throughout the city.

# %%
from shapely import Point, LineString

# %%
join['line'] = join.apply(lambda row: LineString([row['geometry'], row['centroid']]), axis=1) #Create a linestring column
join.head(1)
# Out:
#                                                 urls   price
# 2  https://losangeles.craigslist.org/wst/apa/d/lo...  2178.0  \
#
#                                          description        lat        long
# 2  welcome to casa de vida apartments west la liv...  34.028928 -118.415252  \
#
#    bedrooms  bathrooms   sqft  park_TF
# 2       0.0        1.0  475.0     True  \
#
#                                          park_T_why
# 2  [parks nearby, public parks, public park, parks]  \
#
#                          geometry  index_right  OBJECTID
# 2  POINT (1961650.114 558751.186)          274       275  \
#
#                           PARK_NAME  RPT_ACRES             ADDRESS
# 2  Palms Park (City of Los Angeles)      2.703  2950  Overland Ave  \
#
#           CITY    ZIP    Shape__Area  Shape__Length
# 2  Los Angeles  90064  117732.124023    2484.284534  \
#
#                          centroid    distance
# 2  POINT (1961480.614 559268.459)  462.655676  \
#
#                                                 line
# 2  LINESTRING (1961650.114 558751.186, 1961480.61...

# %%
line_gdf = join[["urls", "PARK_NAME", "line", "centroid", "geometry"]].set_geometry('line')
line_gdf.crs = crs={"init":"epsg:3497"}
line_gdf.head(1)
# Out:
# /Users/mcressy/anaconda3/envs/uds/lib/python3.9/site-packages/pyproj/crs/crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
#                                                 urls
# 2  https://losangeles.craigslist.org/wst/apa/d/lo...  \
#
#                           PARK_NAME
# 2  Palms Park (City of Los Angeles)  \
#
#                                                 line
# 2  LINESTRING (1961650.114 558751.186, 1961480.61...  \
#
#                          centroid                        geometry
# 2  POINT (1961480.614 559268.459)  POINT (1961650.114 558751.186)

# %%
parks.to_crs('EPSG:4326', inplace=True)
parktrue.to_crs('EPSG:4326', inplace=True)
line_gdf.to_crs('EPSG:4326', inplace=True)

# %%
import geopandas as gpd
import matplotlib.pyplot as plt
import contextily as ctx

fig, ax = plt.subplots(figsize=(15, 15))

# Plot the polygons
parks.plot(ax=ax, color='lightblue', edgecolor='black', legend=True)

# Plot the points
parktrue.plot(ax=ax, color='red', markersize=5, legend=True)

# Plot the lines
line_gdf.plot(ax=ax, color='green', linewidth=2, legend=True)

# Set the title and axis labels
ax.set_title('Listings and Parks in Metropolitan Los Angeles', fontsize = 20)
ax.set_xlabel('Longitude')
ax.set_ylabel('Latitude')
ctx.add_basemap(ax, zoom=12, url=ctx.providers.CartoDB.Voyager, crs=4326)
ax.set_xlim(-118.65, -118.1)
ax.set_ylim(33.7, 34.2)
ax.set_axis_off()
# Show the plot
plt.show()

# %% [markdown]
# Beyond the visual relationship between the listings and parks, we plot a histogram to see how apartments are clustered spatially in relation to parks. We see the largest number of listings between 200 and 400 meters from parks, declining progressively every two hundred meters. Interestingly, the closer distance of less than 200 meters has fewer listings than those between 200 and 600 meters.

# %%
import seaborn as sns
ax = sns.histplot(data=join, x="distance", bins=7)

ax.set(xlabel='Distance in meters',
       ylabel='Number of listings',
       title='Apartment listing distance from parks')

#display barplot
plt.show()

# %% [markdown]
# This analysis suffers does suffer from limitations. Because our distance category is based off nearest parks, this does not actually account for different parks that may be listed in the listings than those it is connected with through the sjoin.nearest command. Given more time, we could normalize the language between the datasets and connect them based off of mention. Those listings that only mention parks more broadly could be connected with the nearest parks.
#
# Additionally, we were unable to connect listing point data to the edge of park polygons, using polygon centroids instead. This has the effect of increasing distances, negligibly with smaller parks but significantly with larger parks.

# %% [markdown]
# When running a regression between price and distance there does not seem to be much of a relationship, besides a slight negative relationship. Controlling for bedroom size by dividing rental price by number of bedrooms similarly does not show much of a relationship between price and distance to parks. Our data is limited and has its limitations, making extrapolation difficult. Further research should be conducted on a fuller dataset that also incorporates other sources and accounts for listings that do not list parks but are near them nonetheless.

# %%
ax = sns.regplot(x="distance", y="price", data=join)

# %%
import numpy as np
join['price_control'] = np.where(join['bedrooms'] == 0, join['price'] / 1, 
                                            join['price'] / join['bedrooms'])

# %%
ax = sns.regplot(x="distance", y="price_control", data=join)

# %% [markdown]
# Here we can see, as the histogram displayed, that the mean and median of listings are clustered roughly a quarter mile from parks.

# %%
join['distance'].mean()
# Out:
# 429.93113121443895

# %%
join['distance'].median()
# Out:
# 372.4081001089532

# %%
join.to_pickle("./parkdistance.pkl")
